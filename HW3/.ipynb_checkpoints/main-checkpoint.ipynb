# %%
import numpy as np
from scipy.integrate import quad

import matplotlib.pyplot as plt
plt.rcParams.update({
    'text.latex.preamble': r'\usepackage{amsmath}',
    'text.usetex': True,
    'font.family': 'sans-serif',
    'font.sans-serif': ['Helvetica']
})

# %%
def trap_quad(f,a,b,N=10):
    x_i = np.linspace(a,b,N+1)
    h   = (b-a)/N
    w_i = h/2*np.array([1]+(N-1)*[2]+[1])
    f_i = f(x_i)
    return np.sum(w_i*f_i)

def rom_quad(f,a,b,N=10,R=2):
    I1  = trap_quad(f,a,b,N)
    IR  = trap_quad(f,a,b,R*N)
    err = 1/(R**2 - 1)*(IR - I1)
    return IR+err

def gauss_quad(f,a,b,n=10):
    u_i,w_i = np.polynomial.legendre.leggauss(n)
    x_i = (b-a)*u_i/2 + (a+b)/2
    f_i = f(x_i)
    Jac = (b-a)/2
    return np.sum(Jac*w_i*f_i)

# %% [markdown]
# # Problem 1

# %%
sets = {
    1: [lambda t: t**3,[0,1],0.25],
    2: [lambda t: np.exp(t),[0,1],np.e-1],
    3: [lambda t: np.sin(t),[0,np.pi],2]
}

# %%
N = 10*np.arange(1,11)
results = {1:{},2:{},3:{}}
for i in sets:
    f,ab,exact = sets[i]
    results[i]['trap']    = np.array([trap_quad(f,*ab,_) for _ in N])
    results[i]['rom']     = np.array([rom_quad(f,*ab,int(_/2),2) for _ in N])
    results[i]['gauss']   = gauss_quad(f,*ab)
    results[i]['scipy_v'] = quad(f,*ab)[0]
    results[i]['scipy_e'] = quad(f,*ab)[1]
    results[i]['exact']   = exact

# %%
nrows,ncols = 2,3
fig,ax = plt.subplots(nrows=nrows,ncols=ncols,figsize=(7*ncols,7),gridspec_kw={'height_ratios': [6,1]})

labels = [
    r'$\int_{0}^{1} x^3 {\rm d}{x} = 1/4$',
    r'$\int_{0}^{1} e^{x} {\rm d}{x} = e-1$',
    r'$\int_{0}^{\pi} \sin{x} {\rm d}{x} = 2$'
]
for i in results:
    ax[0][i-1].set_title(labels[i-1],size=30)
    ax[0][i-1].axhline(y=results[i]['exact'],color='k',ls='--',label=r'$\rm exact$')
    ax[0][i-1].fill_between(N,results[i]['scipy_v']+results[i]['scipy_e'],results[i]['scipy_v']-results[i]['scipy_e'],color='g',label=r'$\rm scipy~quad$')
    ax[0][i-1].axhline(y=results[i]['gauss'],color='k',alpha=0.3,lw=4,label=r'${\rm Gauss}~(n=10)$')
    ax[0][i-1].plot(N,results[i]['trap'],color='r',ls='--',marker='.',markersize=10,label=r'$\rm trapezoid$')
    ax[0][i-1].plot(N,results[i]['rom'],color='c',ls='--',marker='x',markersize=10,label=r'$\rm Romberg$')
    
    ax[1][i-1].axhline(y=1,color='k',ls='--',label=r'$\rm exact$')
    ax[1][i-1].fill_between(N,(results[i]['scipy_v']+results[i]['scipy_e'])/results[i]['exact'],(results[i]['scipy_v']-results[i]['scipy_e'])/results[i]['exact'],color='g')
    ax[1][i-1].axhline(y=results[i]['gauss']/results[i]['exact'],color='k',alpha=0.3,lw=4)
    ax[1][i-1].plot(N,results[i]['trap']/results[i]['exact'],color='r',ls='--',marker='.',markersize=10)
    ax[1][i-1].plot(N,results[i]['rom']/results[i]['exact'],color='c',ls='--',marker='x',markersize=10)
    
    ax[1][i-1].set_xlabel(r'$N$',size=30)
    ax[1][i-1].set_ylim(0.97,1.03)
    for j in range(2):
        ax[j][i-1].tick_params(axis='both',which='major',direction='in',labelsize=20)
    ax[0][i-1].tick_params(axis='x',which='major',direction='in',labelsize=0)

ax[0][0].legend(fontsize=20,loc='upper right',frameon=False)    

fig.tight_layout(h_pad=0,w_pad=2)
plt.show()
fig.savefig(r'prob1.pdf',bbox_inches='tight')

# %% [markdown]
# # Problem 2

# %%
sets = {
    1: [lambda t: 1/(1-0.998*t**2),[0,1]],
    2: [lambda t: t*np.sin(30*t)*np.cos(50*t),[0,2*np.pi]],
    3: [lambda t: t/(np.exp(t) - 1),[0,1]],
    4: [lambda t: t*np.sin(1/t),[0,1]]
}

# %%
N = 100
results = {}
for i in sets:
    f,ab = sets[i]
    results[i] = {}
    results[i]['trap']  = trap_quad(f,*ab,N=N)
    results[i]['rom']   = rom_quad(f,*ab,N=int(N/2))
    results[i]['gauss'] = gauss_quad(f,*ab)
    results[i]['scipy'] = quad(f,*ab)
# Out:
# /var/folders/_b/29vq0z955j77svdys97cr5p40000gn/T/ipykernel_97940/4220751577.py:9: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   results[i]['scipy'] = quad(f,*ab)
# /var/folders/_b/29vq0z955j77svdys97cr5p40000gn/T/ipykernel_97940/3396054777.py:4: RuntimeWarning: invalid value encountered in true_divide
#   3: [lambda t: t/(np.exp(t) - 1),[0,1]],
# /var/folders/_b/29vq0z955j77svdys97cr5p40000gn/T/ipykernel_97940/3396054777.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   4: [lambda t: t*np.sin(1/t),[0,1]]
# /var/folders/_b/29vq0z955j77svdys97cr5p40000gn/T/ipykernel_97940/3396054777.py:5: RuntimeWarning: invalid value encountered in sin
#   4: [lambda t: t*np.sin(1/t),[0,1]]

# %%
results
# Out:
# {1: {'trap': 5.362792610474358,
#   'rom': 4.633139993416674,
#   'gauss': 3.1754328415840654,
#   'scipy': (3.8037565146509946, 1.2978109417894528e-09)},
#  2: {'trap': 0.27168690119723077,
#   'rom': 0.31949148341043526,
#   'gauss': 3.3033693305627905,
#   'scipy': (0.1178097245096171, 7.06627363204228e-07)},
#  3: {'trap': nan,
#   'rom': nan,
#   'gauss': 0.777504634112248,
#   'scipy': (0.7775046341122483, 8.63203546544176e-15)},
#  4: {'trap': nan,
#   'rom': nan,
#   'gauss': 0.38705586893341254,
#   'scipy': (0.37852612368669714, 7.057603282345504e-07)}}

# %% [markdown]
# # Problem 3

# %%
def gauss_quad_improper(f,a,b,n=10):
    f_ = lambda t: f(np.tan(t))/np.cos(t)**2
    
    if b == np.inf:
        b = np.pi/2
    else:
        b = np.arctan(b)
    
    if a == -np.inf:
        a = -np.pi/2
    else:
        a = np.arctan(a)
        
    return gauss_quad(f_,a,b,n)

# %%
func = lambda t: np.exp(-t**2)/(1+t**2)
print(gauss_quad_improper(func,0,np.inf,n=10))
print(quad(func,0,np.inf))
print()

func = lambda t: t*np.sin(t)/(1 + t**2)
print(gauss_quad_improper(func,0,np.inf,n=10))
print(quad(func,0,np.inf))
print()

func = lambda t: np.exp(-np.sqrt(t))*np.cos(2*t)
print(gauss_quad_improper(func,0,np.inf,n=1000))
print(quad(func,0,np.inf))
print()
# Out:
# 0.6716176690224877
# (0.6716467108233677, 2.0983641132449105e-09)
#
# -2.1175642947491844
# (1.2549750860426019, 3.29029976362302)
#
# 0.1221786481267515
# (0.12298786975757665, 0.00016636746003028958)
# /var/folders/_b/29vq0z955j77svdys97cr5p40000gn/T/ipykernel_97940/4179935766.py:8: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   print(quad(func,0,np.inf))
# /var/folders/_b/29vq0z955j77svdys97cr5p40000gn/T/ipykernel_97940/4179935766.py:13: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   print(quad(func,0,np.inf))

# %%
0.6716467108233677
0.5778636748954609
0.1229709152892961
# Out:
# 0.1229709152892961

# %% [markdown]
# # Problem 4

# %%
func = lambda t: t**(-1/3)
print(gauss_quad(func,0,1,n=100))
print(quad(func,0,1))
print()

func = lambda t: 1 + 1/t
print(gauss_quad(func,-1,0,n=10) + gauss_quad(func,0,1,n=10))
print(quad(func,-1,0)[0] + quad(func,0,1)[0])
print()

func = lambda t: 1/((t-1)*(t**2+1))
print(gauss_quad_improper(func,-np.inf,1,n=100) + gauss_quad_improper(func,1,np.inf,n=100))
print(quad(func,-100,100))
# Out:
# 1.499140742939651
# (1.5, 6.661338147750939e-15)
# 2.0
# 2.0
# -1.0214901824585567
# (-1.5707969920369633, 1.491570933431774e-08)
# /var/folders/_b/29vq0z955j77svdys97cr5p40000gn/T/ipykernel_97940/2012756465.py:7: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   print(quad(func,-1,0)[0] + quad(func,0,1)[0])
# /var/folders/_b/29vq0z955j77svdys97cr5p40000gn/T/ipykernel_97940/2012756465.py:11: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   print(quad(func,-100,100))

# %% [markdown]
# # Problem 5

# %%
gauss_quad(lambda x: gauss_quad(lambda y: np.sin(x**2 + y**2),0,2,n=100),-1,1,n=100)
# Out:
# 1.7532390605941761

# %%
def f(x,y):
    return 1/np.sqrt(x+y)/(1+x+y)**2

I1 = lambda x: quad(f,0,1-x,args=(x,))[0]
quad(I1,0,1)[0]
# Out:
# 0.28539816339745094

# %% [markdown]
# # Problem 6

# %%
def adaptive_gauss_quad(f,a,b,n=10,reps=1e-10,aeps=1e-20):
    I1 = gauss_quad(f,a,b)
    
    m  = (a+b)/2
    I2 = gauss_quad(f,a,m,n) + gauss_quad(f,m,b,n)
    
    adiff = np.abs(I2 - I1)
    rdiff = np.abs(adiff/(I1 + 1e-100))
    if adiff < aeps or rdiff < reps:
        return I2
    else:
        return gauss_quad(f,a,m,n)+gauss_quad(f,m,b,n)

# %%
sets = {
    1: [lambda t: 1/(1-0.998*t**2),[0,1]],
    2: [lambda t: t*np.sin(30*t)*np.cos(50*t),[0,2*np.pi]],
    3: [lambda t: t/(np.exp(t) - 1),[0,1]],
    4: [lambda t: t*np.sin(1/t),[0,1]]
}

# %%
N = 100
results = {}
for i in sets:
    f,ab = sets[i]
    print(f'{i}: {adaptive_gauss_quad(f,*ab,n=100)}')
# Out:
# 1: 3.803756467401873
# 2: 0.11780972450961652
# 3: 0.7775046341122483
# 4: 0.37861988190548146

# %%
3.803756514650994
0.1178097245096172
0.7775046341122483
0.3785300171241613
# Out:
# 0.3785300171241613

# %% [markdown]
# # Derive quadrature points

# %%
import sympy as sp

# %%
w1,w2 = sp.symbols(r'w_1 w_2')
t1,t2 = sp.symbols(r't_1 t_2')

eq1 = sp.Eq(w1+w2,2)
eq2 = sp.Eq(w1*t1+w2*t2,0)
eq3 = sp.Eq(w1*t1**2+w2*t2**2,2/sp.S(3))
eq4 = sp.Eq(w1*t1**3+w2*t2**3,0)

sp.solve([eq1,eq2,eq3,eq4],[w1,w2,t1,t2],dict=True)
# Out:
# [{w_1: 1, w_2: 1, t_1: -sqrt(3)/3, t_2: sqrt(3)/3},
#  {w_1: 1, w_2: 1, t_1: sqrt(3)/3, t_2: -sqrt(3)/3}]
